# %%
import pandas as pd

df = pd.read_csv("train.csv")
df.shape
# Out:
# (233234, 814)

# %%
df.dtypes.value_counts()
# Out:
# int64      608
# float64    201
# object       5
# Name: count, dtype: int64

# %%
import seaborn as sns

sns.displot(x="utility_agent1", data=df, kind="kde", height=6, aspect=3)

# %%
df().plot(kind="bar", figsize=(20, 6))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df().plot(kind="bar", figsize=(20, 6))
#
# TypeError: 'DataFrame' object is not callable

# %%
from pprint import pprint

object_vars = df.select_dtypes("object").columns

pprint(df[object_vars[0]].value_counts())
# Out:
# GameRulesetName
# Pathway                                          222
# Double_Chess                                     214
# Greater_Even_Loss                                212
# Resolve                                          212
# Ludus_Latrunculorum8x8_Seega_Rules_Suggested     210
#                                                 ...
# Bheri_Bakhri                                      72
# 58_HolesTab_Parallel_Connections_D6_Suggested     72
# CeelkoqyuqkoqijiFourteen_holes_Observed           72
# 58_HolesTab_Unmarked_Suggested                    70
# Faraday                                            4
# Name: count, Length: 1377, dtype: int64

# %%
df_test = pd.read_csv("test.csv")
df_test.shape
# Out:
# (3, 810)

# %%
import matplotlib.pyplot as plt

df.num_wins_agent1.hist(alpha=0.5, legend=True)
df.num_draws_agent1.hist(alpha=0.5, legend=True)
df.num_losses_agent1.hist(alpha=0.5, legend=True)
plt.legend()

# %%
targets = ["num_wins_agent1", "num_draws_agent1", "num_losses_agent1"]
data = df[targets].sum(axis=1)
data.name = "data"

sns.displot(x=data, kind="kde")

# %%
data.agg(["min", "max"])
# Out:
# min    15
# max    45
# Name: data, dtype: int64

# %%
data.value_counts()
# Out:
# data
# 15    230434
# 30      2788
# 45        12
# Name: count, dtype: int64

# %%
df.nunique().plot(kind="bar")
# Out:
# <Axes: >
